# %% [markdown]
# # Data Transformation: Grouping

# %%
df.groupby('Outlet_Size').count()
# Out:
#              Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# Outlet_Size
# High                     927          927               927              927
# Medium                  2730         2730              2730             2730
# Small                   2379         2379              2379             2379
#
#              Item_Type  Item_MRP  Outlet_Identifier  \
# Outlet_Size
# High               927       927                927
# Medium            2730      2730               2730
# Small             2379      2379               2379
#
#              Outlet_Establishment_Year  Outlet_Location_Type  Outlet_Type  \
# Outlet_Size
# High                               927                   927          927
# Medium                            2730                  2730         2730
# Small                             2379                  2379         2379
#
#              Item_Outlet_Sales  rowno
# Outlet_Size
# High                       927    927
# ...

# %%
df.groupby('Outlet_Size').agg({'Item_Outlet_Sales': np.sum})
# Out:
#              Item_Outlet_Sales
# Outlet_Size
# High               2100718.844
# Medium             6952972.703
# Small              4492658.608

# %%
df.groupby('Outlet_Size').agg({'Item_Outlet_Sales': np.sum})
# Out:
#              Item_Outlet_Sales
# Outlet_Size
# High               2100718.844
# Medium             6952972.703
# Small              4492658.608

# %%
df.groupby(['Outlet_Size','Outlet_Location_Type']).agg({'Item_Outlet_Sales': np.sum})
# Out:
#                                   Item_Outlet_Sales
# Outlet_Size Outlet_Location_Type
# High        Tier 3                     2.100719e+06
# Medium      Tier 1                     2.161404e+06
#             Tier 3                     4.791569e+06
# Small       Tier 1                     2.256244e+06
#             Tier 2                     2.236414e+06

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df.groupby(['Item_Fat_Content','Outlet_Location_Type']).agg({'Item_Outlet_Sales': np.sum})
# Out:
#                                        Item_Outlet_Sales
# Item_Fat_Content Outlet_Location_Type
# Low Fat          Tier 1                     2.779760e+06
#                  Tier 2                     4.045053e+06
#                  Tier 3                     4.588351e+06
# Regular          Tier 1                     1.637888e+06
#                  Tier 2                     2.286539e+06
#                  Tier 3                     2.492277e+06

# %%
df_f=df.groupby(['Item_Fat_Content','Outlet_Location_Type']).agg({'Item_Outlet_Sales': np.sum})

# %% [markdown]
# ### Analyzing statistics by group
#
# following statistical functions are available at groupby dataframes level.
#
# | Function | Description |
# |:---------|:------------|
# | mean() | Compute mean of groups |
# | sum() | Compute sum of group values |
# | size() | Compute group sizes |
# | count() | Compute count of group |
# | std() | Standard deviation of groups |
# | var() | Compute variance of groups |
# | sem() | Standard error of the mean of groups |
# | describe() | Generates descriptive statistics |
# | first() |  Compute first of group values |
# | last() | Compute last of group values |
# | nth() | Take nth value, or a subset if n is a list |
# | min() | Compute min of group values |
# | max() | Compute max of group values |

# %%
df.groupby(['Item_Fat_Content','Outlet_Location_Type']).agg({'Item_Outlet_Sales': np.mean})
# Out:
#                                        Item_Outlet_Sales
# Item_Fat_Content Outlet_Location_Type
# Low Fat          Tier 1                      1812.099266
#                  Tier 2                      2249.751161
#                  Tier 3                      2157.193565
# Regular          Tier 1                      1936.037794
#                  Tier 2                      2357.256663
#                  Tier 3                      2152.225523

# %%
df.groupby(['Item_Fat_Content','Outlet_Location_Type']).agg({'Item_Outlet_Sales': np.mean}).describe()
# Out:
#        Item_Outlet_Sales
# count           6.000000
# mean         2110.760662
# std           201.831958
# min          1812.099266
# 25%          1990.084726
# 50%          2154.709544
# 75%          2226.611762
# max          2357.256663

# %% [markdown]
# ## Video 20: Filtering

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df[df['Outlet_Type']=='Supermarket Type1']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750          Regular         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
df[(df['Outlet_Type']=='Supermarket Type1') & (df['Outlet_Location_Type']=='Tier 1')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...              ...          ...              ...              ...
# 8475           NCS17       18.600          Low Fat         0.080627
# 8479           FDL10        8.395          Low Fat         0.039554
# 8492           FDT34        9.300          Low Fat         0.174350
# 8517           FDF53       20.750          Regular         0.083607
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df[(df['Outlet_Type']=='Supermarket Type1') | (df['Outlet_Location_Type']=='Tier 1')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750          Regular         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
df[(df['Outlet_Type']=='Supermarket Type1') | (df['Outlet_Establishment_Year']=='1999')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750          Regular         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...
