# %% [markdown]
# #Data Transformation: Merging

# %%
#Merge creates inner join by default, if not specified explicitely.
pd.merge(split_item, split_outlet, on='rowno')
# Out:
#       rowno Item_Identifier  Item_Weight  Item_MRP  Item_Visibility  \
# 0         0           FDA15        9.300  249.8092         0.016047
# 1         1           DRC01        5.920   48.2692         0.019278
# 2         2           FDN15       17.500  141.6180         0.016760
# 3         3           FDX07       19.200  182.0950         0.000000
# 4         4           NCD19        8.930   53.8614         0.000000
# ...     ...             ...          ...       ...              ...
# 8428   8518           FDF22        6.865  214.5218         0.056783
# 8429   8519           FDS36        8.380  108.1570         0.046982
# 8430   8520           NCJ29       10.600   85.1224         0.035186
# 8431   8521           FDN46        7.210  103.1332         0.145221
# 8432   8522           DRG01       14.800   75.4670         0.044878
#
#                   Item_Type  Item_Outlet_Sales_x Outlet_Identifier  \
# 0                     Dairy            3735.1380            OUT049
# ...

# %%
pd.merge(split_item, split_outlet.iloc[:,[0,1,2,3,4,5]], on='rowno')
# Out:
#       rowno Item_Identifier  Item_Weight  Item_MRP  Item_Visibility  \
# 0         0           FDA15        9.300  249.8092         0.016047
# 1         1           DRC01        5.920   48.2692         0.019278
# 2         2           FDN15       17.500  141.6180         0.016760
# 3         3           FDX07       19.200  182.0950         0.000000
# 4         4           NCD19        8.930   53.8614         0.000000
# ...     ...             ...          ...       ...              ...
# 8428   8518           FDF22        6.865  214.5218         0.056783
# 8429   8519           FDS36        8.380  108.1570         0.046982
# 8430   8520           NCJ29       10.600   85.1224         0.035186
# 8431   8521           FDN46        7.210  103.1332         0.145221
# 8432   8522           DRG01       14.800   75.4670         0.044878
#
#                   Item_Type  Item_Outlet_Sales Outlet_Identifier  \
# 0                     Dairy          3735.1380            OUT049
# ...

# %%
pd.merge(split_item, split_outlet.iloc[:,[0,1,2,3,4,5]], on='rowno',how='inner')
# Out:
#       rowno Item_Identifier  Item_Weight  Item_MRP  Item_Visibility  \
# 0         0           FDA15        9.300  249.8092         0.016047
# 1         1           DRC01        5.920   48.2692         0.019278
# 2         2           FDN15       17.500  141.6180         0.016760
# 3         3           FDX07       19.200  182.0950         0.000000
# 4         4           NCD19        8.930   53.8614         0.000000
# ...     ...             ...          ...       ...              ...
# 8428   8518           FDF22        6.865  214.5218         0.056783
# 8429   8519           FDS36        8.380  108.1570         0.046982
# 8430   8520           NCJ29       10.600   85.1224         0.035186
# 8431   8521           FDN46        7.210  103.1332         0.145221
# 8432   8522           DRG01       14.800   75.4670         0.044878
#
#                   Item_Type  Item_Outlet_Sales Outlet_Identifier  \
# 0                     Dairy          3735.1380            OUT049
# ...

# %%
 split_outlet.iloc[1:5,[0,1,2,3,4,5]]
# Out:
#    rowno Outlet_Identifier Outlet_Establishment_Year Outlet_Location_Type  \
# 1      1            OUT018                      2009               Tier 3
# 2      2            OUT049                      1999               Tier 1
# 3      3            OUT010                      1998               Tier 3
# 4      4            OUT013                      1987               Tier 3
#
#          Outlet_Type Outlet_Size
# 1  Supermarket Type2      Medium
# 2  Supermarket Type1      Medium
# 3      Grocery Store         NaN
# 4  Supermarket Type1        High

# %%
pd.merge(split_item, split_outlet.iloc[1:5,[0,1,2,3,4,5]], on='rowno',how='left')
# Out:
#       rowno Item_Identifier  Item_Weight  Item_MRP  Item_Visibility  \
# 0         0           FDA15        9.300  249.8092         0.016047
# 1         1           DRC01        5.920   48.2692         0.019278
# 2         2           FDN15       17.500  141.6180         0.016760
# 3         3           FDX07       19.200  182.0950         0.000000
# 4         4           NCD19        8.930   53.8614         0.000000
# ...     ...             ...          ...       ...              ...
# 8428   8518           FDF22        6.865  214.5218         0.056783
# 8429   8519           FDS36        8.380  108.1570         0.046982
# 8430   8520           NCJ29       10.600   85.1224         0.035186
# 8431   8521           FDN46        7.210  103.1332         0.145221
# 8432   8522           DRG01       14.800   75.4670         0.044878
#
#                   Item_Type  Item_Outlet_Sales Outlet_Identifier  \
# 0                     Dairy          3735.1380               NaN
# ...

# %%
pd.merge(split_item, split_outlet.iloc[1:5,[0,1,2,3,4,5]], on='rowno',how='right')
# Out:
#    rowno Item_Identifier  Item_Weight  Item_MRP  Item_Visibility  \
# 0      1           DRC01         5.92   48.2692         0.019278
# 1      2           FDN15        17.50  141.6180         0.016760
# 2      3           FDX07        19.20  182.0950         0.000000
# 3      4           NCD19         8.93   53.8614         0.000000
#
#                Item_Type  Item_Outlet_Sales Outlet_Identifier  \
# 0            Soft Drinks           443.4228            OUT018
# 1                   Meat          2097.2700            OUT049
# 2  Fruits and Vegetables           732.3800            OUT010
# 3              Household           994.7052            OUT013
#
#   Outlet_Establishment_Year Outlet_Location_Type        Outlet_Type  \
# 0                      2009               Tier 3  Supermarket Type2
# 1                      1999               Tier 1  Supermarket Type1
# 2                      1998               Tier 3      Grocery Store
# ...
