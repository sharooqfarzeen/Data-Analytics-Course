# %% [markdown]
# ## Data standardization
#
# Data standardization is another scaling technique. In this, the mean of the feature becomes zero and the resultant distribution has a unit standard deviation(mean = 0, std = 1).

# %%
#let us restore back the original dfrt 
dfrt=dfrt2.copy()
dfrt
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8428           FDF22          Low Fat         0.056783            Snack Foods
# 8429           FDS36          Regular         0.046982           Baking Goods
# 8430           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8431           FDN46          Regular         0.145221            Snack Foods
# 8432           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
# data standardization with  sklearn
from sklearn.preprocessing import StandardScaler

# copy of datasets
dfrtstand = dfrt.copy()

# %%
# numerical features
ncols = ['Item_Weight','Item_Visibility','Item_MRP']

# apply standardization on numerical features
for i in ncols:
    # fit on data columns
    scale = StandardScaler().fit(dfrtstand[[i]])
    # transform the data
    dfrtstand[i] = scale.transform(dfrtstand[[i]])

dfrtstand
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat        -0.970363                  Dairy
# 1              DRC01          Regular        -0.907882            Soft Drinks
# 2              FDN15          Low Fat        -0.956579                   Meat
# 3              FDX07          Regular        -1.280691  Fruits and Vegetables
# 4              NCD19          Low Fat        -1.280691              Household
# ...              ...              ...              ...                    ...
# 8428           FDF22          Low Fat        -0.182596            Snack Foods
# 8429           FDS36          Regular        -0.372130           Baking Goods
# 8430           NCJ29          Low Fat        -0.600247     Health and Hygiene
# 8431           FDN46          Regular         1.527632            Snack Foods
# 8432           DRG01          Low Fat        -0.412820            Soft Drinks
#
# ...
