# %%
from google.colab import data_table

data_table.enable_dataframe_formatter()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Print Last 5 Rows

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %% [markdown]
# ## Read TSV file

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab/24 Introduction to EDA/cities.tsv", sep = '\t', header = None)

df.columns = ['Code', 'Name', 'Pin', 'Avg. Income']

print(df.shape)
# Out:
# (10, 4)

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab/24 Introduction to EDA/cities.tsv", sep = '\t')
# Out:
#    AC               Acrelândia  12538  1807.92
# 0  AL             Boca da Mata  25776   186.53
# 1  AL                   Capela  17077   242.62
# 2  AP          Tartarugalzinho  12563  6709.66
# 3  BA          América Dourada     \N   837.72
# 4  CE   Jijoca de Jericoacoara  17002   204.79
# 5  GO               Cavalcante   9392  6953.67
# 6  MA  Centro Novo do Maranhão  17622  8258.42
# 7  MS          Ped\\ro G\\omes   7967  3651.18
# 8  MG      Abadia dos Dourados   6704   881.06

# %% [markdown]
# ## Change Datatype

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

df.Item_Fat_Content = df.Item_Fat_Content.astype('category')
df. Outlet_Type = df. Outlet_Type.astype('category')
df.Outlet_Establishment_Year = df.Outlet_Establishment_Year.astype('str')

print(df.dtypes)
# Out:
# Item_Identifier                object
# Item_Weight                   float64
# Item_Fat_Content             category
# Item_Visibility               float64
# Item_Type                      object
# Item_MRP                      float64
# Outlet_Identifier              object
# Outlet_Establishment_Year      object
# Outlet_Size                    object
# Outlet_Location_Type           object
# Outlet_Type                  category
# Item_Outlet_Sales             float64
# dtype: object

# %% [markdown]
# ## Descriptive Summary

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ## Most Common Outlet Size

# %%
## Open and read data file as specified in the question
## Print the required output in given format
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

print(df.describe(include = 'all').loc['top','Outlet_Size'])
# Out:
# Medium

# %% [markdown]
# ## Item Outlet Sales

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

sns.displot(df.Item_Outlet_Sales)

skew = round(df.Item_Outlet_Sales.skew(), 2)

print(skew)

print("Right-Skewed") if (skew > 0) else print("Left-Skewed")
# Out:
# 1.18
# Right-Skewed

# %% [markdown]
# ## Numerical Variables

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

df.select_dtypes(include=[np.number]).dtypes
# Out:
# Item_Weight                  float64
# Item_Visibility              float64
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# Variation from Mean

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

sns.displot(df.Item_Visibility)

print("Lower") if (df.Item_Visibility.skew() > 0) else print("Higher")
# Out:
# Lower

# %% [markdown]
# ## Item Weight

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

plt.figure(figsize = (12, 8))
sns.boxplot(df.Item_Weight)

print(0)
# Out:
# <Axes: >

# %% [markdown]
# ## Separations

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

sns.displot(df['Item_MRP'], kde = False, color ='red', bins = 200)

print(4)

# %% [markdown]
# ## Plot Relationships

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

sns.pairplot(df, y_vars = 'Item_Outlet_Sales', x_vars = ['Item_Weight', 'Item_Visibility', 'Item_MRP'])

# %%
df.corr().loc['Item_MRP', 'Item_Outlet_Sales']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ee9830f692b7> in <cell line: 1>()
# ----> 1 df.corr().loc['Item_Weight', 'Item_Outlet_Sales']
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Most Item Outlet Sales

# %% [markdown]
# Plot the relationship between “Item_Outlet_Sales” and “Item_Type” using the appropriate plot. And print the item type having maximum item outlet sales.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

plt.figure(figsize = (25,8))
sns.barplot(df, x = 'Item_Type', y = 'Item_Outlet_Sales')

print("Starchy Foods")
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ## Least Outlet Type Sales

# %% [markdown]
# Your task is to figure out how to show her the output and the relation of “ItemOutletsales” and the “Outlet_type” visually.
# Expected Output
#  Outlet type with the least number of sales.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

plt.figure(figsize = (25,8))
sns.barplot(x = df.Outlet_Type, y = df.Item_Outlet_Sales)

print("Grocery Store")
# Out:
# Grocery Store

# %% [markdown]
# ## Outlet Comparison

# %% [markdown]
# Plot a graph using the x-axis as "OutletEstablishmentYear" and the y-axis as "ItemOutletSales". After plotting the graph, observe the values and determine if the old outlets are more profitable than the new ones.
# Note: Here, old means stores opened before the year 2000.
# Expected Output
# Print "Yes" if the observation is true; otherwise, print "No".

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/24 Introduction to EDA/bigmart.csv")

plt.figure(figsize = (25,8))
sns.barplot(x = df.Outlet_Establishment_Year, y = df.Item_Outlet_Sales)

print("No")
# Out:
# No
